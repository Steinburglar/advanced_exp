# %% [markdown]
# Analysis notebook for Lucas, Casey and Cooke's Frank-Hertz lab

# %%
import numpy as np
import pandas as pd
from frank_hertz.Dataloader import *
from frank_hertz.Analysis import *

# %%
data = create_dataframe("../Databases/Frank_Hertz_points.csv")
print(data)
slope, intercept, slope_error, intercept_error = linear_fit(data)
print("slope:" + str(slope))
print(" intercept:" + str(intercept))
print("slope error:" + str(slope_error))
print("intercept error:" + str(intercept_error))
plot_data(data, slope, intercept)
# Out:
#                img  V_max  n     x  sigma_x  big_sigma        V  sigma_V  \
# 0   BBL_1922v_186c  19.22  1  28.0      1.0        1.0  10.7632   0.3844
# 1   BBL_1922v_186c  19.22  2  41.0      1.0        1.0  15.7604   0.3844
# 2   BBL_1931v_164c  19.31  1  29.0      0.5        1.0  11.1998   0.1931
# 3   BBL_1931v_164c  19.31  2  42.5      1.0        1.0  16.4135   0.3862
# 4   BBL_4803v_183c  48.03  1  12.0      1.0        1.0  11.5272   0.9606
# 5   BBL_4803v_183c  48.03  2  16.5      1.0        1.0  15.8499   0.9606
# 6   BBL_4803v_183c  48.03  3  23.0      1.0        1.0  22.0938   0.9606
# 7   BBL_4803v_183c  48.03  4  29.0      1.0        1.0  27.8574   0.9606
# 8    BBL4832v_182c  48.32  1  11.5      0.5        1.0  11.1136   0.4832
# 9    BBL4832v_182c  48.32  2  17.0      0.5        1.0  16.4288   0.4832
# 10   BBL4832v_182c  48.32  3  22.0      1.0        1.0  21.2608   0.9664
# 11   BBL4832v_182c  48.32  4  27.5      1.0        1.0  26.5760   0.9664
# ...
